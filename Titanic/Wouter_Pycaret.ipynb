# %% [markdown]
# # Pycaret model Titanic - Wouter Selis

# %% [markdown]
# ## Install needed libraries to use pycaret.

# %%
#!pip install pandas
#!pip install numpy
#!pip install pycaret
#!pip install openpyxl

# %% [markdown]
# ## Loading the data

# %%
import pandas as pd
import numpy as np
import category_encoders as ce

# Load a sheet into a DataFrame by its name
df = pd.read_excel('files/titanic3.xlsx')

# We are going to change these outliers to the mean price that has been paid by the other passengers, we could do this by simply changing
# the fare price of these passengers but let's use the technique that would be used when there are more than a few outliers
# We use the outlier detection and removal technique

# Calculate the IQR (InterQuartile Range) for the fare column
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bound for outliers, (sidenote, normally the multiplier used to calculate the lower and upper bound is around 1.5
# but this would cause the identification of normal data as outliers resulting in a lot of good data to be lost because it is flagged as an
# outlier. This is why we use such a high multiplier value.
lower_bound = Q1 - 10 * IQR
upper_bound = Q3 + 10 * IQR

# Filter the data to exclude outliers
df = df[(df['fare'] >= lower_bound) & (df['fare'] <= upper_bound)]

df['firstname']=df['name'].str.split(r'[,.]', expand=True)[2]
df['title']=df['name'].str.split(r'[,.]', expand=True)[1]
df['lastname']=df['name'].str.split(r'[,.]', expand=True)[0]

df.drop('name', axis = 1, inplace = True)

normalized_titles = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Major":      "Officer",
    "Jonkheer":   "Royal",
    "Don":        "Royal",
    "Sir" :       "Royal",
    "Dr":         "Officer",
    "Rev":        "Officer",
    "the Countess":"Royal",
    "Dona":       "Royal",
    "Mme":        "Mrs",
    "Mlle":       "Miss",
    "Ms":         "Mrs",
    "Mr" :        "Mr",
    "Mrs" :       "Mrs",
    "Miss" :      "Miss",
    "Master" :    "Master",
    "Lady" :      "Royal"
}
# Strip leading and trailing spaces from the 'title' column
df['title'] = df['title'].str.strip()

# Now, apply the mapping to change original values to new values
df['title'] = df['title'].map(normalized_titles)

# Calculate the mean age for non-null values
mean_age = df['age'].mean()

# Calculate the standard deviation of the age column, which will be used to generate random but believable age values
std_age = df['age'].std()

# Create a mask to identify rows with "Master" or "Miss" in the "title" column
master_miss_mask = (df['title'] == 'Master') | (df['title'] == 'Miss')

# Generate random values for rows with "Master" or "Miss" based on a different standard deviation
random_values_master_miss = np.random.normal(loc=0, scale=std_age * 0.5, size=master_miss_mask.sum())

# Shift the distribution to have the same mean as the original data
added_values_master_miss = random_values_master_miss + mean_age

# Update the 'age' column for rows with "Master" or "Miss" individually
master_miss_indices = df.index[master_miss_mask]
for i, index in enumerate(master_miss_indices):
    # Ensure that the age does not exceed 18
    age = min(added_values_master_miss[i], 18)
    df.loc[index, 'age'] = age

# For all other missing values, use the previously calculated random values
random_values = np.random.normal(loc=0, scale=std_age, size=df['age'].isna().sum())
added_values = random_values + mean_age

# Update the 'age' column for all other missing values individually
other_indices = df.index[~master_miss_mask & df['age'].isna()]
for i, index in enumerate(other_indices):
    df.loc[index, 'age'] = added_values[i]

# Change the datatype of the age column from float to int
df['age'] = df['age'].astype(int)


df['cabin'].fillna(0, inplace=True)

# Replace non-null values with 1 without having problems because there are non-numerical values
df['cabin'] = df['cabin'].apply(lambda x: 1 if x != 0 else x)

# There are 2 null values in the embarked column, because it is such a small amount of data we simply change it to the value 'Q'
# which stands for Queenstown
df['embarked'] = df['embarked'].replace(np.nan, 'Q')


df['boat'].fillna(0, inplace=True)

# Replace non-null values with 1 without having problems because there are non-numerical values
df['boat'] = df['boat'].apply(lambda x: 1 if x != 0 else x)


df['body'].fillna(0, inplace=True)

# Replace non-null values with 1 without having problems because there are non-numerical values
df['body'] = df['body'].apply(lambda x: 1 if x != 0 else x)
# We change the datatype from float to int
df['body'] = df['body'].astype(int)

df.drop('home.dest', axis = 1, inplace = True)

df['survived'] = df['survived'].astype(bool)
df['boat'] = df['boat'].astype(bool)
df['body'] = df['body'].astype(bool)
df['embarked'] = str(df['embarked'])

encoder = ce.OrdinalEncoder(cols=['sex'])
df_encoded = encoder.fit_transform(df)

# %% [markdown]
# ## Import module

# %%
from pycaret.classification import *

# %% [markdown]
# ## Setup the Pycaret environment
# Initialize the training environment and create the transformation pipeline to prepare the data for modeling and deployment. Target is set on survived because this is what we want to predict.

# %%
s = setup(df_encoded, target = 'survived', session_id = 123)
# Out:
# <style type="text/css">
# #T_fd829_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fd829">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd829_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fd829_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd829_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd829_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fd829_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd829_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fd829_row1_col1" class="data row1 col1" >survived</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd829_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fd829_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd829_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fd829_row3_col1" class="data row3 col1" >(1304, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd829_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fd829_row4_col1" class="data row4 col1" >(1304, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd829_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fd829_row5_col1" class="data row5 col1" >(912, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd829_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fd829_row6_col1" class="data row6 col1" >(392, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd829_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fd829_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd829_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_fd829_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd829_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_fd829_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fd829_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_fd829_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fd829_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_fd829_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fd829_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_fd829_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fd829_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_fd829_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fd829_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_fd829_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fd829_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_fd829_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fd829_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_fd829_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fd829_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_fd829_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fd829_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_fd829_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fd829_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_fd829_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fd829_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_fd829_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fd829_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fd829_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_fd829_row21_col1" class="data row21 col1" >1a3d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compare the models
# Here we compare the outcomes of all the models. Every highest score is marked in yellow. We can see that Logistic Regression scores overall the best.

# %%
# functional API
best = compare_models()
print(best)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             21:45:37
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_166c7 th {
#   text-align: left;
# }
# #T_166c7_row0_col0, #T_166c7_row0_col3, #T_166c7_row1_col0, #T_166c7_row1_col2, #T_166c7_row1_col3, #T_166c7_row2_col0, #T_166c7_row2_col1, #T_166c7_row2_col2, #T_166c7_row2_col3, #T_166c7_row2_col4, #T_166c7_row2_col5, #T_166c7_row2_col6, #T_166c7_row2_col7, #T_166c7_row3_col0, #T_166c7_row3_col1, #T_166c7_row3_col2, #T_166c7_row3_col4, #T_166c7_row3_col5, #T_166c7_row3_col6, #T_166c7_row3_col7, #T_166c7_row4_col0, #T_166c7_row4_col1, #T_166c7_row4_col2, #T_166c7_row4_col3, #T_166c7_row4_col4, #T_166c7_row4_col5, #T_166c7_row4_col6, #T_166c7_row4_col7, #T_166c7_row5_col0, #T_166c7_row5_col1, #T_166c7_row5_col2, #T_166c7_row5_col3, #T_166c7_row5_col4, #T_166c7_row5_col5, #T_166c7_row5_col6, #T_166c7_row5_col7, #T_166c7_row6_col0, #T_166c7_row6_col1, #T_166c7_row6_col2, #T_166c7_row6_col3, #T_166c7_row6_col4, #T_166c7_row6_col5, #T_166c7_row6_col6, #T_166c7_row6_col7, #T_166c7_row7_col0, #T_166c7_row7_col1, #T_166c7_row7_col2, #T_166c7_row7_col3, #T_166c7_row7_col4, #T_166c7_row7_col5, #T_166c7_row7_col6, #T_166c7_row7_col7, #T_166c7_row8_col0, #T_166c7_row8_col1, #T_166c7_row8_col2, #T_166c7_row8_col3, #T_166c7_row8_col4, #T_166c7_row8_col5, #T_166c7_row8_col6, #T_166c7_row8_col7, #T_166c7_row9_col0, #T_166c7_row9_col1, #T_166c7_row9_col2, #T_166c7_row9_col3, #T_166c7_row9_col4, #T_166c7_row9_col5, #T_166c7_row9_col6, #T_166c7_row9_col7, #T_166c7_row10_col0, #T_166c7_row10_col1, #T_166c7_row10_col2, #T_166c7_row10_col3, #T_166c7_row10_col4, #T_166c7_row10_col5, #T_166c7_row10_col6, #T_166c7_row10_col7, #T_166c7_row11_col0, #T_166c7_row11_col1, #T_166c7_row11_col2, #T_166c7_row11_col3, #T_166c7_row11_col4, #T_166c7_row11_col5, #T_166c7_row11_col6, #T_166c7_row11_col7, #T_166c7_row12_col0, #T_166c7_row12_col1, #T_166c7_row12_col2, #T_166c7_row12_col3, #T_166c7_row12_col4, #T_166c7_row12_col5, #T_166c7_row12_col6, #T_166c7_row12_col7 {
#   text-align: left;
# }
# #T_166c7_row0_col1, #T_166c7_row0_col2, #T_166c7_row0_col4, #T_166c7_row0_col5, #T_166c7_row0_col6, #T_166c7_row0_col7, #T_166c7_row1_col1, #T_166c7_row1_col4, #T_166c7_row1_col5, #T_166c7_row1_col6, #T_166c7_row1_col7, #T_166c7_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_166c7_row0_col8, #T_166c7_row1_col8, #T_166c7_row4_col8, #T_166c7_row5_col8, #T_166c7_row6_col8, #T_166c7_row7_col8, #T_166c7_row9_col8, #T_166c7_row10_col8, #T_166c7_row11_col8, #T_166c7_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_166c7_row2_col8, #T_166c7_row3_col8, #T_166c7_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_166c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_166c7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_166c7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_166c7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_166c7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_166c7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_166c7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_166c7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_166c7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_166c7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_166c7_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_166c7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_166c7_row0_col1" class="data row0 col1" >0.9791</td>
#       <td id="T_166c7_row0_col2" class="data row0 col2" >0.9939</td>
#       <td id="T_166c7_row0_col3" class="data row0 col3" >0.9566</td>
#       <td id="T_166c7_row0_col4" class="data row0 col4" >0.9884</td>
#       <td id="T_166c7_row0_col5" class="data row0 col5" >0.9719</td>
#       <td id="T_166c7_row0_col6" class="data row0 col6" >0.9554</td>
#       <td id="T_166c7_row0_col7" class="data row0 col7" >0.9561</td>
#       <td id="T_166c7_row0_col8" class="data row0 col8" >0.4480</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_166c7_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_166c7_row1_col1" class="data row1 col1" >0.9791</td>
#       <td id="T_166c7_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_166c7_row1_col3" class="data row1 col3" >0.9566</td>
#       <td id="T_166c7_row1_col4" class="data row1 col4" >0.9884</td>
#       <td id="T_166c7_row1_col5" class="data row1 col5" >0.9719</td>
#       <td id="T_166c7_row1_col6" class="data row1 col6" >0.9554</td>
#       <td id="T_166c7_row1_col7" class="data row1 col7" >0.9561</td>
#       <td id="T_166c7_row1_col8" class="data row1 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_166c7_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_166c7_row2_col1" class="data row2 col1" >0.9375</td>
#       <td id="T_166c7_row2_col2" class="data row2 col2" >0.9746</td>
#       <td id="T_166c7_row2_col3" class="data row2 col3" >0.8703</td>
#       <td id="T_166c7_row2_col4" class="data row2 col4" >0.9635</td>
#       <td id="T_166c7_row2_col5" class="data row2 col5" >0.9134</td>
#       <td id="T_166c7_row2_col6" class="data row2 col6" >0.8647</td>
#       <td id="T_166c7_row2_col7" class="data row2 col7" >0.8688</td>
#       <td id="T_166c7_row2_col8" class="data row2 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_166c7_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_166c7_row3_col1" class="data row3 col1" >0.9342</td>
#       <td id="T_166c7_row3_col2" class="data row3 col2" >0.9805</td>
#       <td id="T_166c7_row3_col3" class="data row3 col3" >0.9653</td>
#       <td id="T_166c7_row3_col4" class="data row3 col4" >0.8779</td>
#       <td id="T_166c7_row3_col5" class="data row3 col5" >0.9183</td>
#       <td id="T_166c7_row3_col6" class="data row3 col6" >0.8636</td>
#       <td id="T_166c7_row3_col7" class="data row3 col7" >0.8679</td>
#       <td id="T_166c7_row3_col8" class="data row3 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_166c7_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_166c7_row4_col1" class="data row4 col1" >0.9189</td>
#       <td id="T_166c7_row4_col2" class="data row4 col2" >0.9789</td>
#       <td id="T_166c7_row4_col3" class="data row4 col3" >0.8390</td>
#       <td id="T_166c7_row4_col4" class="data row4 col4" >0.9449</td>
#       <td id="T_166c7_row4_col5" class="data row4 col5" >0.8867</td>
#       <td id="T_166c7_row4_col6" class="data row4 col6" >0.8240</td>
#       <td id="T_166c7_row4_col7" class="data row4 col7" >0.8296</td>
#       <td id="T_166c7_row4_col8" class="data row4 col8" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_166c7_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_166c7_row5_col1" class="data row5 col1" >0.8311</td>
#       <td id="T_166c7_row5_col2" class="data row5 col2" >0.9404</td>
#       <td id="T_166c7_row5_col3" class="data row5 col3" >0.6744</td>
#       <td id="T_166c7_row5_col4" class="data row5 col4" >0.8533</td>
#       <td id="T_166c7_row5_col5" class="data row5 col5" >0.7503</td>
#       <td id="T_166c7_row5_col6" class="data row5 col6" >0.6260</td>
#       <td id="T_166c7_row5_col7" class="data row5 col7" >0.6381</td>
#       <td id="T_166c7_row5_col8" class="data row5 col8" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_166c7_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_166c7_row6_col0" class="data row6 col0" >S
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Test the best model
# Now we want to test the best model (logistic regression) on our dataset.
# In the column 'prediction_label' we can see if our model predicted if the person survived or not. 1 = survived & 0 = dead.
# In the column 'prediction_score' we can see how sure our model thinks it has predicted the right outcome.

# %%
predict_model(best, data=df_encoded)
# Out:
# <style type="text/css">
# </style>
# <table id="T_14f96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14f96_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_14f96_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_14f96_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_14f96_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_14f96_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_14f96_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_14f96_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_14f96_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14f96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14f96_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_14f96_row0_col1" class="data row0 col1" >0.9755</td>
#       <td id="T_14f96_row0_col2" class="data row0 col2" >0.9970</td>
#       <td id="T_14f96_row0_col3" class="data row0 col3" >0.9536</td>
#       <td id="T_14f96_row0_col4" class="data row0 col4" >0.9813</td>
#       <td id="T_14f96_row0_col5" class="data row0 col5" >0.9673</td>
#       <td id="T_14f96_row0_col6" class="data row0 col6" >0.9477</td>
#       <td id="T_14f96_row0_col7" class="data row0 col7" >0.9479</td>
#     </tr>
#   </tbody>
# </table>
#       pclass  sex  age  sibsp  parch  ticket        fare  cabin  \
# 0          1    1   18      0      0   24160  211.337494      1
# 1          1    2   18      1      2  113781  151.550003      1
# 2          1    1   18      1      2  113781  151.550003      1
# 3          1    2   30      1      2  113781  151.550003      1
# 4          1    1   25      1      2  113781  151.550003      1
# ...      ...  ...  ...    ...    ...     ...         ...    ...
# 1304       3    1   18      1      0    2665   14.454200      0
# 1305       3    1   18      1      0    2665   14.454200      0
# 1306       3    2   26      0      0    2656    7.225000      0
# 1307       3    2   27      0      0    2670    7.225000      0
# 1308       3    2   29      0      0  315082    7.875000      0
#
#                                                embarked   boat   body  \
# 0     0       S\n1       S\n2       S\n3       S\n4 ...   True  False
# 1     0       S\n1       S\n2       S\n3       S\n4 ...   True  False
# 2     0       S\n1       S\n2       S\n3       S\n4 ...  False  False
# 3     0       S\n1       S\n2       S\n3       S\n4 ...  False   True
# 4     0       S\n1       S\n2       S\n3       S\n4 ...  False  False
# ...                                                 ...    ...    ...
# 1304  0       S\n1       S\n2       S\n3       S\n4 ...  False   True
# 1305  0       S\n1       S\n2       S\n3       S\n4 ...  False  False
# 1306  0       S\n1       S\n2       S\n3       S\n4 ...  False   True
# 1307  0       S\n1       S\n2       S\n3       S\n4 ...  False  False
# 1308  0       S\n1       S\n2       S\n3       S\n4 ...  False  False
#
#                                firstname   title   lastname  survived  \
# 0                       Elisabeth Walton    Miss      Allen      True
# 1                          Hudson Trevor  Master    Allison      True
# 2                          Helen Loraine    Miss    Allison     False
# 3                Hudson Joshua Creighton      Mr    Allison     False
# 4      Hudson J C (Bessie Waldo Daniels)     Mrs    Allison     False
# ...                                  ...     ...        ...       ...
# 1304                              Hileni    Miss     Zabour     False
# 1305                             Thamine    Miss     Zabour     False
# 1306                         Mapriededer      Mr   Zakarian     False
# 1307                               Ortin      Mr   Zakarian     False
# 1308                                 Leo      Mr  Zimmerman     False
#
#       prediction_label  prediction_score
# 0                    1            0.9946
# 1                    1            0.9645
# 2                    0            0.8568
# 3                    0            0.9934
# 4                    0            0.7319
# ...                ...               ...
# 1304                 0            0.9572
# 1305                 0            0.8863
# 1306                 0            0.9948
# 1307                 0            0.9835
# 1308                 0            0.9868
#
# [1304 rows x 17 columns]

# %% [markdown]
# Get the accuracy to compare it later on.

# %%
measures = pull()

# %% [markdown]
# ## Save model
# Finally we can save the model in our files folder.

# %%
save_model(best, 'files/titanic_pycaret_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['pclass', 'sex', 'age', 'sibsp',
#                                               'parch', 'fare', 'cabin'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   Transforme...
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'files/titanic_pycaret_model.pkl')

# %% [markdown]
# ## Load model
# If I want to reuse this model I can simply load it from my files folder

# %%
loaded_model = load_model('files/titanic_pycaret_model')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\woute\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['pclass', 'sex', 'age', 'sibsp',
#                                              'parch', 'fare', 'cabin'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecat...
#                                                               handle_unknown='value',
#                                                               hierarchy=None,
#                                                               min_samples_leaf=20,
#                                                               return_df=True,
#                                                               smoothing=10,
#                                                               verbose=0))),
#                 ('trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=123,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Without column 'boat' & 'body'
# In previous model we used the dataset with feature boat and body included. Obviously when someone was on a boat their survival chance is greater then someone who was in the cold water. Also when they found the body of a person, this person obviously died. This means that when we include these 2 features in our dataset the model will almost only look at those 2 features to make predictions. To see the differnce in performance we will now create a model without these 2 features.

# %% [markdown]
# Here we are going to drop our column boat and body from our dataset.

# %%
df_exclude = df_encoded
df_exclude = df_exclude.drop(['boat', 'body'], axis=1)
df_exclude
# Out:
#       pclass  survived  sex  age  sibsp  parch  ticket      fare  cabin  \
# 0          1      True    1   18      0      0   24160  211.3375      1
# 1          1      True    2   18      1      2  113781  151.5500      1
# 2          1     False    1   18      1      2  113781  151.5500      1
# 3          1     False    2   30      1      2  113781  151.5500      1
# 4          1     False    1   25      1      2  113781  151.5500      1
# ...      ...       ...  ...  ...    ...    ...     ...       ...    ...
# 1304       3     False    1   18      1      0    2665   14.4542      0
# 1305       3     False    1   18      1      0    2665   14.4542      0
# 1306       3     False    2   26      0      0    2656    7.2250      0
# 1307       3     False    2   27      0      0    2670    7.2250      0
# 1308       3     False    2   29      0      0  315082    7.8750      0
#
#                                                embarked  \
# 0     0       S\n1       S\n2       S\n3       S\n4 ...
# 1     0       S\n1       S\n2       S\n3       S\n4 ...
# 2     0       S\n1       S\n2       S\n3       S\n4 ...
# 3     0       S\n1       S\n2       S\n3       S\n4 ...
# 4     0       S\n1       S\n2       S\n3       S\n4 ...
# ...                                                 ...
# 1304  0       S\n1       S\n2       S\n3       S\n4 ...
# 1305  0       S\n1       S\n2       S\n3       S\n4 ...
# 1306  0       S\n1       S\n2       S\n3       S\n4 ...
# 1307  0       S\n1       S\n2       S\n3       S\n4 ...
# 1308  0       S\n1       S\n2       S\n3       S\n4 ...
#
#                                firstname   title   lastname
# 0                       Elisabeth Walton    Miss      Allen
# 1                          Hudson Trevor  Master    Allison
# 2                          Helen Loraine    Miss    Allison
# 3                Hudson Joshua Creighton      Mr    Allison
# 4      Hudson J C (Bessie Waldo Daniels)     Mrs    Allison
# ...                                  ...     ...        ...
# 1304                              Hileni    Miss     Zabour
# 1305                             Thamine    Miss     Zabour
# 1306                         Mapriededer      Mr   Zakarian
# 1307                               Ortin      Mr   Zakarian
# 1308                                 Leo      Mr  Zimmerman
#
# [1304 rows x 13 columns]

# %% [markdown]
# ## Create and test model

# %%
s_exclude = setup(df_exclude, target = 'survived', session_id = 123)

# functional API
best_exclude = compare_models()
print(best_exclude)

predict_model(best_exclude, data=df_exclude)

measures_exclude = pull()

save_model(best_exclude, 'files/titanic_exluded_pycaret_model')

loaded_exclude_model = load_model('files/titanic_exluded_pycaret_model')
print(loaded_exclude_model)
# Out:
# <style type="text/css">
# #T_4b214_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4b214">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b214_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4b214_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b214_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b214_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4b214_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b214_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4b214_row1_col1" class="data row1 col1" >survived</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b214_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4b214_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b214_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4b214_row3_col1" class="data row3 col1" >(1304, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b214_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4b214_row4_col1" class="data row4 col1" >(1304, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b214_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4b214_row5_col1" class="data row5 col1" >(912, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b214_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4b214_row6_col1" class="data row6 col1" >(392, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b214_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4b214_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b214_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_4b214_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b214_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4b214_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4b214_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4b214_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4b214_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4b214_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4b214_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4b214_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4b214_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_4b214_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4b214_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_4b214_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4b214_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_4b214_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4b214_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_4b214_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4b214_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_4b214_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4b214_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_4b214_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4b214_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_4b214_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4b214_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_4b214_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4b214_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4b214_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_4b214_row21_col1" class="data row21 col1" >37e7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_135ec th {
#   text-align: left;
# }
# #T_135ec_row0_col0, #T_135ec_row1_col0, #T_135ec_row1_col1, #T_135ec_row1_col2, #T_135ec_row1_col3, #T_135ec_row1_col4, #T_135ec_row1_col5, #T_135ec_row1_col6, #T_135ec_row1_col7, #T_135ec_row2_col0, #T_135ec_row2_col1, #T_135ec_row2_col2, #T_135ec_row2_col3, #T_135ec_row2_col4, #T_135ec_row2_col5, #T_135ec_row2_col6, #T_135ec_row2_col7, #T_135ec_row3_col0, #T_135ec_row3_col1, #T_135ec_row3_col2, #T_135ec_row3_col3, #T_135ec_row3_col4, #T_135ec_row3_col5, #T_135ec_row3_col6, #T_135ec_row3_col7, #T_135ec_row4_col0, #T_135ec_row4_col1, #T_135ec_row4_col2, #T_135ec_row4_col3, #T_135ec_row4_col4, #T_135ec_row4_col5, #T_135ec_row4_col6, #T_135ec_row4_col7, #T_135ec_row5_col0, #T_135ec_row5_col1, #T_135ec_row5_col2, #T_135ec_row5_col3, #T_135ec_row5_col4, #T_135ec_row5_col5, #T_135ec_row5_col6, #T_135ec_row5_col7, #T_135ec_row6_col0, #T_135ec_row6_col1, #T_135ec_row6_col2, #T_135ec_row6_col3, #T_135ec_row6_col4, #T_135ec_row6_col5, #T_135ec_row6_col6, #T_135ec_row6_col7, #T_135ec_row7_col0, #T_135ec_row7_col1, #T_135ec_row7_col2, #T_135ec_row7_col3, #T_135ec_row7_col4, #T_135ec_row7_col5, #T_135ec_row7_col6, #T_135ec_row7_col7, #T_135ec_row8_col0, #T_135ec_row8_col1, #T_135ec_row8_col2, #T_135ec_row8_col3, #T_135ec_row8_col4, #T_135ec_row8_col5, #T_135ec_row8_col6, #T_135ec_row8_col7, #T_135ec_row9_col0, #T_135ec_row9_col1, #T_135ec_row9_col2, #T_135ec_row9_col3, #T_135ec_row9_col4, #T_135ec_row9_col5, #T_135ec_row9_col6, #T_135ec_row9_col7, #T_135ec_row10_col0, #T_135ec_row10_col1, #T_135ec_row10_col2, #T_135ec_row10_col3, #T_135ec_row10_col4, #T_135ec_row10_col5, #T_135ec_row10_col6, #T_135ec_row10_col7, #T_135ec_row11_col0, #T_135ec_row11_col1, #T_135ec_row11_col2, #T_135ec_row11_col3, #T_135ec_row11_col4, #T_135ec_row11_col5, #T_135ec_row11_col6, #T_135ec_row11_col7, #T_135ec_row12_col0, #T_135ec_row12_col1, #T_135ec_row12_col2, #T_135ec_row12_col3, #T_135ec_row12_col4, #T_135ec_row12_col5, #T_135ec_row12_col6, #T_135ec_row12_col7 {
#   text-align: left;
# }
# #T_135ec_row0_col1, #T_135ec_row0_col2, #T_135ec_row0_col3, #T_135ec_row0_col4, #T_135ec_row0_col5, #T_135ec_row0_col6, #T_135ec_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_135ec_row0_col8, #T_135ec_row2_col8, #T_135ec_row3_col8, #T_135ec_row4_col8, #T_135ec_row5_col8, #T_135ec_row6_col8, #T_135ec_row7_col8, #T_135ec_row8_col8, #T_135ec_row9_col8, #T_135ec_row10_col8, #T_135ec_row11_col8, #T_135ec_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_135ec_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_135ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_135ec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_135ec_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_135ec_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_135ec_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_135ec_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_135ec_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_135ec_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_135ec_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_135ec_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_135ec_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_135ec_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_135ec_row0_col1" class="data row0 col1" >0.8202</td>
#       <td id="T_135ec_row0_col2" class="data row0 col2" >0.8695</td>
#       <td id="T_135ec_row0_col3" class="data row0 col3" >0.6917</td>
#       <td id="T_135ec_row0_col4" class="data row0 col4" >0.8125</td>
#       <td id="T_135ec_row0_col5" class="data row0 col5" >0.7452</td>
#       <td id="T_135ec_row0_col6" class="data row0 col6" >0.6078</td>
#       <td id="T_135ec_row0_col7" class="data row0 col7" >0.6143</td>
#       <td id="T_135ec_row0_col8" class="data row0 col8" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_135ec_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_135ec_row1_col1" class="data row1 col1" >0.7434</td>
#       <td id="T_135ec_row1_col2" class="data row1 col2" >0.8002</td>
#       <td id="T_135ec_row1_col3" class="data row1 col3" >0.5396</td>
#       <td id="T_135ec_row1_col4" class="data row1 col4" >0.7221</td>
#       <td id="T_135ec_row1_col5" class="data row1 col5" >0.6130</td>
#       <td id="T_135ec_row1_col6" class="data row1 col6" >0.4284</td>
#       <td id="T_135ec_row1_col7" class="data row1 col7" >0.4414</td>
#       <td id="T_135ec_row1_col8" class="data row1 col8" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_135ec_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_135ec_row2_col1" class="data row2 col1" >0.7226</td>
#       <td id="T_135ec_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_135ec_row2_col3" class="data row2 col3" >0.4124</td>
#       <td id="T_135ec_row2_col4" class="data row2 col4" >0.7532</td>
#       <td id="T_135ec_row2_col5" class="data row2 col5" >0.5302</td>
#       <td id="T_135ec_row2_col6" class="data row2 col6" >0.3564</td>
#       <td id="T_135ec_row2_col7" class="data row2 col7" >0.3906</td>
#       <td id="T_135ec_row2_col8" class="data row2 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_135ec_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_135ec_row3_col1" class="data row3 col1" >0.7182</td>
#       <td id="T_135ec_row3_col2" class="data row3 col2" >0.7843</td>
#       <td id="T_135ec_row3_col3" class="data row3 col3" >0.4790</td>
#       <td id="T_135ec_row3_col4" class="data row3 col4" >0.6945</td>
#       <td id="T_135ec_row3_col5" class="data row3 col5" >0.5576</td>
#       <td id="T_135ec_row3_col6" class="data row3 col6" >0.3641</td>
#       <td id="T_135ec_row3_col7" class="data row3 col7" >0.3821</td>
#       <td id="T_135ec_row3_col8" class="data row3 col8" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_135ec_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_135ec_row4_col1" class="data row4 col1" >0.7061</td>
#       <td id="T_135ec_row4_col2" class="data row4 col2" >0.7791</td>
#       <td id="T_135ec_row4_col3" class="data row4 col3" >0.4005</td>
#       <td id="T_135ec_row4_col4" class="data row4 col4" >0.7036</td>
#       <td id="T_135ec_row4_col5" class="data row4 col5" >0.5077</td>
#       <td id="T_135ec_row4_col6" class="data row4 col6" >0.3205</td>
#       <td id="T_135ec_row4_col7" class="data row4 col7" >0.3478</td>
#       <td id="T_135ec_row4_col8" class="data row4 col8" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_135ec_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_135ec_row5_col1" class="data row5 col1" >0.7040</td>
#       <td id="T_135ec_row5_col2" class="data row5 col2" >0.7137</td>
#       <td id="T_135ec_row5_col3" class="data row5 col3" >0.5130</td>
#       <td id="T_135ec_row5_col4" class="data row5 col4" >0.6407</td>
#       <td id="T_135ec_row5_col5" class="data row5 col5" >0.5670</td>
#       <td id="T_135ec_row5_col6" class="data row5 col6" >0.3471</td>
#       <td id="T_135ec_row5_col7" class="data row5 col7" >0.3537</td>
#       <td id="T_135ec_row5_col8" class="data row5 col8" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_135ec_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_135ec_row6_col0" class="data row6 col0" >SVM - L
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# <style type="text/css">
# </style>
# <table id="T_2338e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2338e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2338e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2338e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2338e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2338e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2338e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2338e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2338e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2338e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2338e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_2338e_row0_col1" class="data row0 col1" >0.9202</td>
#       <td id="T_2338e_row0_col2" class="data row0 col2" >0.9726</td>
#       <td id="T_2338e_row0_col3" class="data row0 col3" >0.8387</td>
#       <td id="T_2338e_row0_col4" class="data row0 col4" >0.9455</td>
#       <td id="T_2338e_row0_col5" class="data row0 col5" >0.8889</td>
#       <td id="T_2338e_row0_col6" class="data row0 col6" >0.8270</td>
#       <td id="T_2338e_row0_col7" class="data row0 col7" >0.8306</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\woute\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['pclass', 'sex', 'age', 'sibsp',
#                                              'parch', 'fare', 'cabin'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecat...
#                                                               handle_unknown='value',
#                                                               hierarchy=None,
#                                                               min_samples_leaf=20,
#                                                               return_df=True,
#                                                               smoothing=10,
#                                                               verbose=0))),
#                 ('trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=123,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Lets compare the 2 models.
# We can see that all the measures of the model with the boat & body columns included in the dataset scored a little better then the model without them. We thought that boat & body would make a big difference to predict if a preson survived or not. Using this model it doesn't really make a big difference. When we see at Kieran's model using GradientBoostingRegressor we see that there is a big difference though.

# %% [markdown]
# Accuracy all columns:

# %%
measures
# Out:
#                  Model  Accuracy    AUC  Recall   Prec.      F1   Kappa  \
# 0  Logistic Regression    0.9755  0.997  0.9536  0.9813  0.9673  0.9477
#
#       MCC
# 0  0.9479

# %% [markdown]
# Accuracy without column 'boat' & 'body':

# %%
measures_exclude
# Out:
#                  Model  Accuracy     AUC  Recall   Prec.      F1  Kappa  \
# 0  Logistic Regression    0.9202  0.9726  0.8387  0.9455  0.8889  0.827
#
#       MCC
# 0  0.8306
