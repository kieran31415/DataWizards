# %% [markdown]
# ## Pycaret Model Cropdata - Laurens Karakolev

# %% [markdown]
# We install the needed modules to use pycaret

# %%
# !pip install pandas numpy
# !pip install pycaret
# Out:
# Requirement already satisfied: pandas in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.2)
# Requirement already satisfied: numpy in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: C:\Users\laure\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pycaret in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.1.0)
# Requirement already satisfied: cloudpickle in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: xxhash in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (5.17.0)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.5.2)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (8.1.1)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.1.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (4.1.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.6.2)
# Requirement already satisfied: requests>=2.27.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.27.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: scipy~=1.10.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (8.6.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (5.9.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (4.66.1)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (3.6.2)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: numba>=0.55.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.58.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (3.0.32)
# Requirement already satisfied: matplotlib-inline in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: decorator in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.6.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (5.5.0)
# Requirement already satisfied: colorama in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: backcall in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.3.0->pycaret) (4.38.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat>=4.2.0->pycaret) (4.19.1)
# Requirement already satisfied: fastjsonschema in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat>=4.2.0->pycaret) (2.18.0)
# Requirement already satisfied: jupyter-core in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat>=4.2.0->pycaret) (5.0.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from numba>=0.55.0->pycaret) (0.41.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly>=5.0.0->pycaret) (8.2.3)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.13.0)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.7)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.2)
# Requirement already satisfied: urllib3 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.8)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (65.5.0)
# Requirement already satisfied: six in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.27.1->pycaret) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.27.1->pycaret) (2021.10.8)
# Requirement already satisfied: scikit-base<0.6.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.1)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: retrying in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.8.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.5)
# Requirement already satisfied: nest-asyncio in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: ansi2html in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: wcwidth in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305)
# Requirement already satisfied: platformdirs in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.4)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: pure-eval in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\laure\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: C:\Users\laure\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# We import the libraries.

# %%
from pycaret.regression import *
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import pickle

# %% [markdown]
# ## Dataset Transformation
#
# The explanation of our dataset transformation is described in our EDA file.

# %%
df = pd.read_excel('files/food-twentieth-century-crop-statistics-1900-2017-xlsx.xlsx', sheet_name="CropStats")

df_transformed=df.drop(['Unnamed: 0','admin2','notes'], axis=1)
df_transformed['admin1'].fillna(df['admin0'], inplace=True)

for index, row in df_transformed.iterrows():
    if pd.notna(row['hectares (ha)']) and pd.notna(row['production (tonnes)']) and pd.isna(row['yield(tonnes/ha)']) and row['hectares (ha)'] != 0:
        df_transformed.at[index, 'yield(tonnes/ha)'] = row['production (tonnes)'] / row['hectares (ha)']

df_transformed['yield(tonnes/ha)'].bfill(inplace=True)
df_transformed=df_transformed.drop(['hectares (ha)','production (tonnes)'], axis=1)
df_transformed
# Out:
#        Harvest_year   admin0    admin1   crop  year  yield(tonnes/ha)
# 0              1902  Austria   Austria  wheat  1902          1.310000
# 1              1903  Austria   Austria  wheat  1903          1.470000
# 2              1904  Austria   Austria  wheat  1904          1.270000
# 3              1905  Austria   Austria  wheat  1905          1.330000
# 4              1906  Austria   Austria  wheat  1906          1.280000
# ...             ...      ...       ...    ...   ...               ...
# 36702          2013    China  zhejiang  wheat  2013          3.685117
# 36703          2014    China  zhejiang  wheat  2014          3.768875
# 36704          2015    China  zhejiang  wheat  2015          3.912027
# 36705          2016    China  zhejiang  wheat  2016          3.315054
# 36706          2017    China  zhejiang  wheat  2017          4.043600
#
# [36707 rows x 6 columns]

# %% [markdown]
# We figure out the datatypes of our different features again just see again what is categorical data and what is numerical. See below.

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36707 entries, 0 to 36706
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Harvest_year      36707 non-null  int64
#  1   admin0            36707 non-null  object
#  2   admin1            36707 non-null  object
#  3   crop              36707 non-null  object
#  4   year              36707 non-null  int64
#  5   yield(tonnes/ha)  36707 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Setup the Pycaret environment
# Initialize the training environment and create the transformation pipeline to prepare the data for modeling and deployment. Target is set on yield(tonnes/ha) because this is what we want to predict.

# %%
s = setup(df_transformed, target='yield(tonnes/ha)', session_id=123, numeric_features=['Harvest_year', 'year'], categorical_features=['admin0', 'admin1', 'crop'])
# Out:
# <style type="text/css">
# #T_9903b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9903b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9903b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9903b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9903b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9903b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9903b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9903b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9903b_row1_col1" class="data row1 col1" >yield(tonnes/ha)</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9903b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9903b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9903b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9903b_row3_col1" class="data row3 col1" >(36707, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9903b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9903b_row4_col1" class="data row4 col1" >(36707, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9903b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9903b_row5_col1" class="data row5 col1" >(25694, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9903b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9903b_row6_col1" class="data row6 col1" >(11013, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9903b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9903b_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9903b_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_9903b_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9903b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_9903b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9903b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_9903b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9903b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_9903b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9903b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_9903b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9903b_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_9903b_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9903b_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_9903b_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9903b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9903b_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9903b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9903b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9903b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9903b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9903b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9903b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9903b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9903b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9903b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9903b_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9903b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9903b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9903b_row21_col1" class="data row21 col1" >8010</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compare the models
#
# Here we compare the outcomes of all the models. Every highest score in marked in yellow and we can see that Random Forest Regressor is the winner.

# %%
best = compare_models()
print(best)
# Out:
# <style type="text/css">
# #T_05c06 th {
#   text-align: left;
# }
row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_05c06_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_05c06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05c06_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_05c06_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_05c06_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_05c06_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_05c06_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_05c06_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_05c06_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_05c06_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05c06_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_05c06_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_05c06_row0_col1" class="data row0 col1" >0.2679</td>
#       <td id="T_05c06_row0_col2" class="data row0 col2" >0.2095</td>
#       <td id="T_05c06_row0_col3" class="data row0 col3" >0.4570</td>
#       <td id="T_05c06_row0_col4" class="data row0 col4" >0.9574</td>
#       <td id="T_05c06_row0_col5" class="data row0 col5" >0.1140</td>
#       <td id="T_05c06_row0_col6" class="data row0 col6" >0.1335</td>
#       <td id="T_05c06_row0_col7" class="data row0 col7" >1.6580</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_05c06_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_05c06_row1_col1" class="data row1 col1" >0.2965</td>
#       <td id="T_05c06_row1_col2" class="data row1 col2" >0.2687</td>
#       <td id="T_05c06_row1_col3" class="data row1 col3" >0.5176</td>
#       <td id="T_05c06_row1_col4" class="data row1 col4" >0.9454</td>
#       <td id="T_05c06_row1_col5" class="data row1 col5" >0.1239</td>
#       <td id="T_05c06_row1_col6" class="data row1 col6" >0.1461</td>
#       <td id="T_05c06_row1_col7" class="data row1 col7" >1.5710</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_05c06_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_05c06_row2_col1" class="data row2 col1" >0.3788</td>
#       <td id="T_05c06_row2_col2" class="data row2 col2" >0.3248</td>
#       <td id="T_05c06_row2_col3" class="data row2 col3" >0.5694</td>
#       <td id="T_05c06_row2_col4" class="data row2 col4" >0.9339</td>
#       <td id="T_05c06_row2_col5" class="data row2 col5" >0.1530</td>
#       <td id="T_05c06_row2_col6" class="data row2 col6" >0.2057</td>
#       <td id="T_05c06_row2_col7" class="data row2 col7" >0.1970</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_05c06_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_05c06_row3_col1" class="data row3 col1" >0.3176</td>
#       <td id="T_05c06_row3_col2" class="data row3 col2" >0.3505</td>
#       <td id="T_05c06_row3_col3" class="data row3 col3" >0.5907</td>
#       <td id="T_05c06_row3_col4" class="data row3 col4" >0.9288</td>
#       <td id="T_05c06_row3_col5" class="data row3 col5" >0.1428</td>
#       <td id="T_05c06_row3_col6" class="data row3 col6" >0.1524</td>
#       <td id="T_05c06_row3_col7" class="data row3 col7" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_05c06_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_05c06_row4_col1" class="data row4 col1" >0.5330</td>
#       <td id="T_05c06_row4_col2" class="data row4 col2" >0.5921</td>
#       <td id="T_05c06_row4_col3" class="data row4 col3" >0.7690</td>
#       <td id="T_05c06_row4_col4" class="data row4 col4" >0.8796</td>
#       <td id="T_05c06_row4_col5" class="data row4 col5" >0.2048</td>
#       <td id="T_05c06_row4_col6" class="data row4 col6" >0.2913</td>
#       <td id="T_05c06_row4_col7" class="data row4 col7" >0.4990</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_05c06_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_05c06_row5_col1" class="data row5 col1" >0.5303</td>
#       <td id="T_05c06_row5_col2" class="data row5 col2" >0.6359</td>
#       <td id="T_05c06_row5_col3" class="data row5 col3" >0.7968</td>
#       <td id="T_05c06_row5_col4" class="data row5 col4" >0.8708</td>
#       <td id="T_05c06_row5_col5" class="data row5 col5" >0.2081</td>
#       <td id="T_05c06_row5_col6" class="data row5 col6" >0.2784</td>
#       <td id="T_05c06_row5_col7" class="data row5 col7" >0.1580</td>
#     </tr>
#     <tr>
#       <th id="T_05c06_level
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='squared_error',
#                       max_depth=None, max_features=1.0, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                       oob_score=False, random_state=123, verbose=0,
#                       warm_start=False)

# %% [markdown]
# ## Test best model
#
# Now we test this model on our dataset again but also want to see what it exactly predicted. This is done in the prediction_label column.
# If this was a classification model it would've also given a prediction_score column that depicts how sure it is but Pycaret does not do this for regression models which is logical because in a regression task there is no "score" or probability" like with classification.

# %%
predict_model(best, data=df_transformed)
# Out:
# <style type="text/css">
# </style>
# <table id="T_005a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_005a2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_005a2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_005a2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_005a2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_005a2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_005a2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_005a2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_005a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_005a2_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_005a2_row0_col1" class="data row0 col1" >0.1436</td>
#       <td id="T_005a2_row0_col2" class="data row0 col2" >0.0740</td>
#       <td id="T_005a2_row0_col3" class="data row0 col3" >0.2720</td>
#       <td id="T_005a2_row0_col4" class="data row0 col4" >0.9849</td>
#       <td id="T_005a2_row0_col5" class="data row0 col5" >0.0707</td>
#       <td id="T_005a2_row0_col6" class="data row0 col6" >0.0727</td>
#     </tr>
#   </tbody>
# </table>
#        Harvest_year   admin0    admin1   crop  year  yield(tonnes/ha)  \
# 0              1902  Austria   Austria  wheat  1902          1.310000
# 1              1903  Austria   Austria  wheat  1903          1.470000
# 2              1904  Austria   Austria  wheat  1904          1.270000
# 3              1905  Austria   Austria  wheat  1905          1.330000
# 4              1906  Austria   Austria  wheat  1906          1.280000
# ...             ...      ...       ...    ...   ...               ...
# 36702          2013    China  zhejiang  wheat  2013          3.685117
# 36703          2014    China  zhejiang  wheat  2014          3.768875
# 36704          2015    China  zhejiang  wheat  2015          3.912027
# 36705          2016    China  zhejiang  wheat  2016          3.315054
# 36706          2017    China  zhejiang  wheat  2017          4.043600
#
#        prediction_label
# 0              1.257925
# 1              1.237351
# 2              1.253547
# 3              1.306594
# 4              1.294807
# ...                 ...
# 36702          3.720229
# 36703          3.795209
# 36704          3.871542
# 36705          3.461911
# 36706          3.913650
#
# [36707 rows x 7 columns]

# %% [markdown]
# Get the accuracy to compare it later on.

# %%
measures = pull()

# %% [markdown]
# ## Save the model

# %%
save_model(best, 'files/crop_pycaret_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Harvest_year', 'year'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=...
#                  ('trained_model',
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='squared_error',
#                                         max_depth=None, max_features=1.0,
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=123,
#                                         verbose=0, warm_start=False))],
#           verbose=False),
#  'files/crop_pycaret_model.pkl')

# %% [markdown]
# Let's also make a picklefile which takes way less storage

# %%
filename = 'files/cropdata_pycaret_model.sav'
pickle.dump(best, open(filename, 'wb'))
